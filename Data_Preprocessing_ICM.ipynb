# %% [markdown]
# # **Problem Statement [Click](https://docs.google.com/document/d/1nWKUnD6F76F1AtGFEjyfIVH9oxcBUU1N/edit)**

# %% [markdown]
# # **Data Collection :**

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/praveendecode/Datasets/main/Copper_Set.xlsx%20-%20Result%201.csv')
# Out:
# <ipython-input-196-5b081fd1faaa>:3: DtypeWarning:
#
# Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181673 entries, 0 to 181672
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id             181671 non-null  object
#  1   item_date      181672 non-null  float64
#  2   quantity tons  181673 non-null  object
#  3   customer       181672 non-null  float64
#  4   country        181645 non-null  float64
#  5   status         181671 non-null  object
#  6   item type      181673 non-null  object
#  7   application    181649 non-null  float64
#  8   thickness      181672 non-null  float64
#  9   width          181673 non-null  float64
#  10  material_ref   103754 non-null  object
#  11  product_ref    181673 non-null  int64
#  12  delivery date  181672 non-null  float64
#  13  selling_price  181672 non-null  float64
# dtypes: float64(8), int64(1), object(5)
# memory usage: 19.4+ MB

# %%
df.head()
# Out:
#                                      id   item_date quantity tons    customer  \
# 0  EC06F063-9DF0-440C-8764-0B0C05A4F6AE  20210401.0     54.151139  30156308.0
# 1  4E5F4B3D-DDDF-499D-AFDE-A3227EC49425  20210401.0    768.024839  30202938.0
# 2  E140FF1B-2407-4C02-A0DD-780A093B1158  20210401.0    386.127949  30153963.0
# 3  F8D507A0-9C62-4EFE-831E-33E1DA53BB50  20210401.0    202.411065  30349574.0
# 4  4E1C4E78-152B-430A-8094-ADD889C9D0AD  20210401.0    785.526262  30211560.0
#
#    country status item type  application  thickness   width  \
# 0     28.0    Won         W         10.0       2.00  1500.0
# 1     25.0    Won         W         41.0       0.80  1210.0
# 2     30.0    Won        WI         28.0       0.38   952.0
# 3     32.0    Won         S         59.0       2.30  1317.0
# 4     28.0    Won         W         10.0       4.00  2000.0
#
#                                material_ref  product_ref  delivery date  \
# 0                               DEQ1 S460MC   1670798778     20210701.0
# 1  0000000000000000000000000000000000104991   1668701718     20210401.0
# 2                                  S0380700       628377     20210101.0
# 3                   DX51D+ZM310MAO 2.3X1317   1668701718     20210101.0
# 4                           2_S275JR+AR-CL1       640665     20210301.0
#
#    selling_price
# 0         854.00
# 1        1047.00
# 2         644.33
# 3         768.00
# 4         577.00

# %%
copydf = df.copy()

# %%
copydf.head()
# Out:
#                                      id   item_date quantity tons    customer  \
# 0  EC06F063-9DF0-440C-8764-0B0C05A4F6AE  20210401.0     54.151139  30156308.0
# 1  4E5F4B3D-DDDF-499D-AFDE-A3227EC49425  20210401.0    768.024839  30202938.0
# 2  E140FF1B-2407-4C02-A0DD-780A093B1158  20210401.0    386.127949  30153963.0
# 3  F8D507A0-9C62-4EFE-831E-33E1DA53BB50  20210401.0    202.411065  30349574.0
# 4  4E1C4E78-152B-430A-8094-ADD889C9D0AD  20210401.0    785.526262  30211560.0
#
#    country status item type  application  thickness   width  \
# 0     28.0    Won         W         10.0       2.00  1500.0
# 1     25.0    Won         W         41.0       0.80  1210.0
# 2     30.0    Won        WI         28.0       0.38   952.0
# 3     32.0    Won         S         59.0       2.30  1317.0
# 4     28.0    Won         W         10.0       4.00  2000.0
#
#                                material_ref  product_ref  delivery date  \
# 0                               DEQ1 S460MC   1670798778     20210701.0
# 1  0000000000000000000000000000000000104991   1668701718     20210401.0
# 2                                  S0380700       628377     20210101.0
# 3                   DX51D+ZM310MAO 2.3X1317   1668701718     20210101.0
# 4                           2_S275JR+AR-CL1       640665     20210301.0
#
#    selling_price
# 0         854.00
# 1        1047.00
# 2         644.33
# 3         768.00
# 4         577.00

# %% [markdown]
# # **Data Preprocess :**

# %% [markdown]
# **`Object Creation For Ordinal Encoder`**

# %%
# Convert Categorical data into continous data

from sklearn.preprocessing import OrdinalEncoder

encoder = OrdinalEncoder()

# %%
copydf.columns
# Out:
# Index(['id', 'item_date', 'quantity tons', 'customer', 'country', 'status',
#        'item type', 'application', 'thickness', 'width', 'material_ref',
#        'product_ref', 'delivery date', 'selling_price'],
#       dtype='object')

# %%
copydf.columns = ['id', 'item_date', 'quantity_tons', 'customer', 'country', 'status',
       'item_type', 'application', 'thickness', 'width', 'material_ref',
       'product_ref', 'delivery_date', 'selling_price']

# %% [markdown]
# **`Missing value Count`**

# %%
copydf.isnull().mean()*100  # See Percentage of the missing values
# Out:
# id                0.001101
# item_date         0.000550
# quantity_tons     0.000000
# customer          0.000550
# country           0.015412
# status            0.001101
# item_type         0.000000
# application       0.013211
# thickness         0.000550
# width             0.000000
# material_ref     42.889697
# product_ref       0.000000
# delivery_date     0.000550
# selling_price     0.000550
# dtype: float64

# %% [markdown]
# **`Before Cleaning Process`**

# %%
copydf.isnull().sum() # See total missing values for corresponding columns
# Out:
# id                   2
# item_date            1
# quantity_tons        0
# customer             1
# country             28
# status               2
# item_type            0
# application         24
# thickness            1
# width                0
# material_ref     77919
# product_ref          0
# delivery_date        1
# selling_price        1
# dtype: int64

# %%
print(f'Total missing value : {copydf.isnull().sum().sum()}') # Overall missing value count
# Out:
# Total missing value : 77980

# %% [markdown]
# **`Column Data Types`**

# %%
copydf.dtypes
# Out:
# id                object
# item_date        float64
# quantity_tons     object
# customer         float64
# country          float64
# status            object
# item_type         object
# application      float64
# thickness        float64
# width            float64
# material_ref      object
# product_ref        int64
# delivery_date    float64
# selling_price    float64
# dtype: object

# %% [markdown]
# **`Data Cleaning :`**

# %% [markdown]
# **Treat missing value for 'id' column**

# %%
copydf['id'] = copydf['id'].apply(lambda x : str(x))    # String conversion

copydf['id'].fillna(method='bfill',inplace=True)

print('Total Missing Value :',copydf['id'].isnull().sum())
# Out:
# Total Missing Value : 0

# %% [markdown]
# **Treat missing value for 'item_date' column**

# %%
copydf['item_date'].fillna(method='bfill',inplace=True) # Missing value Filled

copydf['item_date'] = copydf['item_date'].apply(lambda x : str(int(x))) # String Conversion

copydf['item_date'] = copydf['item_date'].apply(lambda x : f'{x[0:4]}-{x[4:6]}-{x[6:8]}')

copydf['item_date_day'] = copydf['item_date'].apply(lambda x : x[8:])

copydf['item_date'] = copydf['item_date'].apply(lambda x :  pd.to_datetime(f'{x[0:4]}-01-01',format='%Y-%m-%d')  if x[5:7] == '00' or x[8:] == '00' or int(x[5:7]) > 12 else pd.to_datetime(x,format='%Y-%m-%d')) # Date format Conversion

copydf['item_date_year'] = pd.to_datetime(copydf['item_date']).dt.year

copydf['item_date_month'] = pd.to_datetime(copydf['item_date']).dt.month

print('Total Missing Value :',copydf['item_date'].isnull().sum())
# Out:
# Total Missing Value : 0

# %% [markdown]
# **Treat Missing Value for "quantity_tons" column**

# %%
copydf['quantity_tons'] = copydf['quantity_tons'].apply(lambda x : float('1000.00') if x == 'e' else float(x))

print('Total Missing Value :',copydf['quantity_tons'].isnull().sum())
# Out:
# Total Missing Value : 0

# %% [markdown]
# **'customer' column**

# %%
copydf['customer'] = copydf['customer'].apply(lambda x : str(x))

copydf['customer'] = copydf['customer'].apply(lambda x : x.split('.'))

copydf['customer'] = copydf['customer'].apply(lambda x : x[0])

# %%
copydf.dtypes
# Out:
# id                         object
# item_date          datetime64[ns]
# quantity_tons             float64
# customer                   object
# country                   float64
# status                     object
# item_type                  object
# application               float64
# thickness                 float64
# width                     float64
# material_ref               object
# product_ref                 int64
# delivery_date             float64
# selling_price             float64
# item_date_day              object
# item_date_year              int64
# item_date_month             int64
# dtype: object

# %% [markdown]
# **Collecting only 'WON' and 'LOST' Status Feature**

# %%
copydf
# Out:
#                                           id  item_date  quantity_tons  \
# 0       EC06F063-9DF0-440C-8764-0B0C05A4F6AE 2021-04-01      54.151139
# 1       4E5F4B3D-DDDF-499D-AFDE-A3227EC49425 2021-04-01     768.024839
# 2       E140FF1B-2407-4C02-A0DD-780A093B1158 2021-04-01     386.127949
# 3       F8D507A0-9C62-4EFE-831E-33E1DA53BB50 2021-04-01     202.411065
# 4       4E1C4E78-152B-430A-8094-ADD889C9D0AD 2021-04-01     785.526262
# ...                                      ...        ...            ...
# 181668  DE633116-D1DF-4846-982E-55EFC3658A76 2020-07-02     102.482422
# 181669  A48374B1-E6DB-45F2-889A-1F9C27C099EB 2020-07-02     208.086469
# 181670  91643238-5C7B-4237-9A5F-63AE3D35F320 2020-07-02       4.235594
# 181671  7AFFD323-01D9-4E15-B80D-7D1B03498FC8 2020-07-02   -2000.000000
# 181672  AD0CA853-AE3C-4B2F-9FBB-8B0B965F84BC 2020-07-02     406.686538
#
#         customer  country status item_type  application  thickness   width  \
# 0       30156308     28.0    Won         W         10.0       2.00  1500.0
# 1       30202938     25.0    Won         W         41.0       0.80  1210.0
# 2       30153963     30.0    Won        WI         28.0       0.38   952.0
# 3       30349574     32.0    Won         S         59.0       2.30  1317.0
# 4       30211560     28.0    Won         W         10.0       4.00  2000.0
# ...          ...      ...    ...       ...          ...        ...     ...
# 181668  30200854     25.0    Won         W         41.0       0.96  1220.0
# 181669  30200854     25.0    Won         W         41.0       0.95  1500.0
# 181670  30200854     25.0    Won         W         41.0       0.71  1250.0
# 181671  30200854     25.0    Won         W         41.0       0.85  1250.0
# 181672  30200854     25.0    Won         W         41.0       0.71  1240.0
#
#                                     material_ref  product_ref  delivery_date  \
# 0                                    DEQ1 S460MC   1670798778     20210701.0
# 1       0000000000000000000000000000000000104991   1668701718     20210401.0
# 2                                       S0380700       628377     20210101.0
# 3                        DX51D+ZM310MAO 2.3X1317   1668701718     20210101.0
# 4                                2_S275JR+AR-CL1       640665     20210301.0
# ...                                          ...          ...            ...
# 181668  0000000000000000000000000000000001000777    164141591     20200701.0
# 181669  0000000000000000000000000000000001000227    164141591     20200701.0
# 181670  0000000000000000000000000000000001004216    164141591     20200701.0
# 181671  0000000000000000000000000000000001001149    164141591     20200701.0
# 181672  0000000000000000000000000000000001005439    164141591     20200701.0
#
#         selling_price item_date_day  item_date_year  item_date_month
# 0              854.00            01            2021                4
# 1             1047.00            01            2021                4
# 2              644.33            01            2021                4
# 3              768.00            01            2021                4
# 4              577.00            01            2021                4
# ...               ...           ...             ...              ...
# 181668         591.00            02            2020                7
# 181669         589.00            02            2020                7
# 181670         619.00            02            2020                7
# 181671         601.00            02            2020                7
# 181672         607.00            02            2020                7
#
# [181673 rows x 17 columns]

# %%
copydf = copydf.drop(['id','material_ref'],axis=1)

new_df = copydf.query('status == "Won" or status == "Lost"')

# %%
new_df
# Out:
#         item_date  quantity_tons  customer  country status item_type  \
# 0      2021-04-01      54.151139  30156308     28.0    Won         W
# 1      2021-04-01     768.024839  30202938     25.0    Won         W
# 2      2021-04-01     386.127949  30153963     30.0    Won        WI
# 3      2021-04-01     202.411065  30349574     32.0    Won         S
# 4      2021-04-01     785.526262  30211560     28.0    Won         W
# ...           ...            ...       ...      ...    ...       ...
# 181668 2020-07-02     102.482422  30200854     25.0    Won         W
# 181669 2020-07-02     208.086469  30200854     25.0    Won         W
# 181670 2020-07-02       4.235594  30200854     25.0    Won         W
# 181671 2020-07-02   -2000.000000  30200854     25.0    Won         W
# 181672 2020-07-02     406.686538  30200854     25.0    Won         W
#
#         application  thickness   width  product_ref  delivery_date  \
# 0              10.0       2.00  1500.0   1670798778     20210701.0
# 1              41.0       0.80  1210.0   1668701718     20210401.0
# 2              28.0       0.38   952.0       628377     20210101.0
# 3              59.0       2.30  1317.0   1668701718     20210101.0
# 4              10.0       4.00  2000.0       640665     20210301.0
# ...             ...        ...     ...          ...            ...
# 181668         41.0       0.96  1220.0    164141591     20200701.0
# 181669         41.0       0.95  1500.0    164141591     20200701.0
# 181670         41.0       0.71  1250.0    164141591     20200701.0
# 181671         41.0       0.85  1250.0    164141591     20200701.0
# 181672         41.0       0.71  1240.0    164141591     20200701.0
#
#         selling_price item_date_day  item_date_year  item_date_month
# 0              854.00            01            2021                4
# 1             1047.00            01            2021                4
# 2              644.33            01            2021                4
# 3              768.00            01            2021                4
# 4              577.00            01            2021                4
# ...               ...           ...             ...              ...
# 181668         591.00            02            2020                7
# 181669         589.00            02            2020                7
# 181670         619.00            02            2020                7
# 181671         601.00            02            2020                7
# 181672         607.00            02            2020                7
#
# [150448 rows x 15 columns]

# %% [markdown]
# **'Country' Column**

# %%
new_df.isnull().sum()
# Out:
# item_date          0
# quantity_tons      0
# customer           0
# country            4
# status             0
# item_type          0
# application        3
# thickness          0
# width              0
# product_ref        0
# delivery_date      1
# selling_price      1
# item_date_day      0
# item_date_year     0
# item_date_month    0
# dtype: int64

# %%
new_df = new_df.dropna(subset=['country'])

# %%
new_df.isnull().sum()
# Out:
# item_date          0
# quantity_tons      0
# customer           0
# country            0
# status             0
# item_type          0
# application        0
# thickness          0
# width              0
# product_ref        0
# delivery_date      1
# selling_price      1
# item_date_day      0
# item_date_year     0
# item_date_month    0
# dtype: int64

# %% [markdown]
# **'Status' Column**

# %%
# Before Conversion

new_df['status'].unique()
# Out:
# array(['Won', 'Lost'], dtype=object)

# %%
# Conversion Process

new_df['status'] = encoder.fit_transform(new_df[['status']])
# Out:
# <ipython-input-220-87f8240af11a>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# After Conversion

new_df['status'].unique()
# Out:
# array([1., 0.])

# %% [markdown]
# **'item_type' Column**

# %%
# Before Converion

new_df['item_type'].unique()
# Out:
# array(['W', 'WI', 'S', 'Others', 'PL', 'IPL', 'SLAWR'], dtype=object)

# %%
# Conversion Process

new_df['item_type'] = encoder.fit_transform(new_df[['item_type']])
# Out:
# <ipython-input-223-308764f86bca>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# After Conversion

new_df['item_type'].unique()
# Out:
# array([5., 6., 3., 1., 2., 0., 4.])

# %% [markdown]
# **'application' Column**

# %%
new_df['application'].unique()
# Out:
# array([10., 41., 28., 59., 15.,  4., 38., 56., 42., 26., 27., 19., 20.,
#        66., 29., 22., 25., 40., 79.,  3., 99.,  2., 67.,  5., 39., 69.,
#        70., 65., 58., 68.])

# %%
new_df['application'].fillna(method='bfill',inplace=True)

new_df['application'] = new_df['application'].apply(lambda x : float(x))
# Out:
# <ipython-input-226-f8f19eacaae3>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-226-f8f19eacaae3>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# **'thickness' Column**

# %%
new_df['thickness'] = new_df['thickness'].apply(lambda x : float(x))
# Out:
# <ipython-input-227-da44be7b608a>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# **'width' Column**

# %%
new_df['width'] = new_df['width'].apply(lambda x : float(x))
# Out:
# <ipython-input-228-f20a142ac132>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
new_df.isnull().sum()
# Out:
# item_date          0
# quantity_tons      0
# customer           0
# country            0
# status             0
# item_type          0
# application        0
# thickness          0
# width              0
# product_ref        0
# delivery_date      1
# selling_price      1
# item_date_day      0
# item_date_year     0
# item_date_month    0
# dtype: int64

# %% [markdown]
# **'product_ref' Column**

# %%
new_df['product_ref'] = new_df['product_ref'] .apply(lambda x : str(x))
# Out:
# <ipython-input-230-d7479220e167>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# **'delivery date' Column**

# %%
new_df
# Out:
#         item_date  quantity_tons  customer  country  status  item_type  \
# 0      2021-04-01      54.151139  30156308     28.0     1.0        5.0
# 1      2021-04-01     768.024839  30202938     25.0     1.0        5.0
# 2      2021-04-01     386.127949  30153963     30.0     1.0        6.0
# 3      2021-04-01     202.411065  30349574     32.0     1.0        3.0
# 4      2021-04-01     785.526262  30211560     28.0     1.0        5.0
# ...           ...            ...       ...      ...     ...        ...
# 181668 2020-07-02     102.482422  30200854     25.0     1.0        5.0
# 181669 2020-07-02     208.086469  30200854     25.0     1.0        5.0
# 181670 2020-07-02       4.235594  30200854     25.0     1.0        5.0
# 181671 2020-07-02   -2000.000000  30200854     25.0     1.0        5.0
# 181672 2020-07-02     406.686538  30200854     25.0     1.0        5.0
#
#         application  thickness   width product_ref  delivery_date  \
# 0              10.0       2.00  1500.0  1670798778     20210701.0
# 1              41.0       0.80  1210.0  1668701718     20210401.0
# 2              28.0       0.38   952.0      628377     20210101.0
# 3              59.0       2.30  1317.0  1668701718     20210101.0
# 4              10.0       4.00  2000.0      640665     20210301.0
# ...             ...        ...     ...         ...            ...
# 181668         41.0       0.96  1220.0   164141591     20200701.0
# 181669         41.0       0.95  1500.0   164141591     20200701.0
# 181670         41.0       0.71  1250.0   164141591     20200701.0
# 181671         41.0       0.85  1250.0   164141591     20200701.0
# 181672         41.0       0.71  1240.0   164141591     20200701.0
#
#         selling_price item_date_day  item_date_year  item_date_month
# 0              854.00            01            2021                4
# 1             1047.00            01            2021                4
# 2              644.33            01            2021                4
# 3              768.00            01            2021                4
# 4              577.00            01            2021                4
# ...               ...           ...             ...              ...
# 181668         591.00            02            2020                7
# 181669         589.00            02            2020                7
# 181670         619.00            02            2020                7
# 181671         601.00            02            2020                7
# 181672         607.00            02            2020                7
#
# [150444 rows x 15 columns]

# %%
new_df['delivery_date'].fillna(method='bfill',inplace=True) # Missing value Filled

new_df['delivery_date'] = new_df['delivery_date'].apply(lambda x : str(x)) # String Conversion

new_df['delivery_date'] = new_df['delivery_date'].apply(lambda x : f'{x[0:4]}-{x[4:6]}-{x[6:8]}')

new_df['delivery_date'] = new_df['delivery_date'].apply(lambda x : '2023-01-01'   if  int(x[:4]) > 2023  else x)

new_df['delivery_date_day'] = new_df['delivery_date'].apply(lambda x : int(x[8:]))

new_df['delivery_date'] = new_df['delivery_date'].apply(lambda x : f'{x[:4]}-12-{x[8:]}'   if  int(x[5:7]) > 12  else x)

new_df['delivery_date'] = pd.to_datetime(new_df['delivery_date']) # Date format Conversion

new_df['delivery_date_month'] = pd.to_datetime(new_df['delivery_date']).dt.month

new_df['delivery_date_year'] = pd.to_datetime(new_df['delivery_date']).dt.year
# Out:
# <ipython-input-232-055f4e51bd5c>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-232-055f4e51bd5c>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-232-055f4e51bd5c>:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-232-055f4e51bd5c>:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-232-055f4e51bd5c>:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-232-055f4e51bd5c>:11: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-232-055f4e51bd5c>:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-232-055f4e51bd5c>:15: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-232-055f4e51bd5c>:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
new_df.dtypes
# Out:
# item_date              datetime64[ns]
# quantity_tons                 float64
# customer                       object
# country                       float64
# status                        float64
# item_type                     float64
# application                   float64
# thickness                     float64
# width                         float64
# product_ref                    object
# delivery_date          datetime64[ns]
# selling_price                 float64
# item_date_day                  object
# item_date_year                  int64
# item_date_month                 int64
# delivery_date_day               int64
# delivery_date_month             int64
# delivery_date_year              int64
# dtype: object

# %% [markdown]
# **Selling Price Column**

# %%
Mean = round(new_df['selling_price'].mean(),3)

new_df['selling_price'].fillna(Mean,inplace=True)

new_df['selling_price'] = new_df['selling_price'].apply(lambda x : float(x))
# Out:
# <ipython-input-234-cbffcbe83cdd>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-234-cbffcbe83cdd>:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
new_df.isnull().sum()
# Out:
# item_date              0
# quantity_tons          0
# customer               0
# country                0
# status                 0
# item_type              0
# application            0
# thickness              0
# width                  0
# product_ref            0
# delivery_date          0
# selling_price          0
# item_date_day          0
# item_date_year         0
# item_date_month        0
# delivery_date_day      0
# delivery_date_month    0
# delivery_date_year     0
# dtype: int64

# %%
new_df
# Out:
#         item_date  quantity_tons  customer  country  status  item_type  \
# 0      2021-04-01      54.151139  30156308     28.0     1.0        5.0
# 1      2021-04-01     768.024839  30202938     25.0     1.0        5.0
# 2      2021-04-01     386.127949  30153963     30.0     1.0        6.0
# 3      2021-04-01     202.411065  30349574     32.0     1.0        3.0
# 4      2021-04-01     785.526262  30211560     28.0     1.0        5.0
# ...           ...            ...       ...      ...     ...        ...
# 181668 2020-07-02     102.482422  30200854     25.0     1.0        5.0
# 181669 2020-07-02     208.086469  30200854     25.0     1.0        5.0
# 181670 2020-07-02       4.235594  30200854     25.0     1.0        5.0
# 181671 2020-07-02   -2000.000000  30200854     25.0     1.0        5.0
# 181672 2020-07-02     406.686538  30200854     25.0     1.0        5.0
#
#         application  thickness   width product_ref delivery_date  \
# 0              10.0       2.00  1500.0  1670798778    2021-07-01
# 1              41.0       0.80  1210.0  1668701718    2021-04-01
# 2              28.0       0.38   952.0      628377    2021-01-01
# 3              59.0       2.30  1317.0  1668701718    2021-01-01
# 4              10.0       4.00  2000.0      640665    2021-03-01
# ...             ...        ...     ...         ...           ...
# 181668         41.0       0.96  1220.0   164141591    2020-07-01
# 181669         41.0       0.95  1500.0   164141591    2020-07-01
# 181670         41.0       0.71  1250.0   164141591    2020-07-01
# 181671         41.0       0.85  1250.0   164141591    2020-07-01
# 181672         41.0       0.71  1240.0   164141591    2020-07-01
#
#         selling_price item_date_day  item_date_year  item_date_month  \
# 0              854.00            01            2021                4
# 1             1047.00            01            2021                4
# 2              644.33            01            2021                4
# 3              768.00            01            2021                4
# 4              577.00            01            2021                4
# ...               ...           ...             ...              ...
# 181668         591.00            02            2020                7
# 181669         589.00            02            2020                7
# 181670         619.00            02            2020                7
# 181671         601.00            02            2020                7
# 181672         607.00            02            2020                7
#
#         delivery_date_day  delivery_date_month  delivery_date_year
# 0                       1                    7                2021
# 1                       1                    4                2021
# 2                       1                    1                2021
# 3                       1                    1                2021
# 4                       1                    3                2021
# ...                   ...                  ...                 ...
# 181668                  1                    7                2020
# 181669                  1                    7                2020
# 181670                  1                    7                2020
# 181671                  1                    7                2020
# 181672                  1                    7                2020
#
# [150444 rows x 18 columns]

# %%
new_df['item_date_day'] = new_df['item_date_day'].apply(lambda x : int(x))
# Out:
# <ipython-input-237-1aada12f24b0>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
new_df['quantity_tons'] = new_df['quantity_tons'].apply(lambda x : 0.0  if x<0.0 else x)
new_df['selling_price'] = new_df['selling_price'].apply(lambda x : 0.0  if x<0.0 else x)
# Out:
# <ipython-input-238-412597b8ea5b>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-238-412597b8ea5b>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
new_df
# Out:
#         item_date  quantity_tons  customer  country  status  item_type  \
# 0      2021-04-01      54.151139  30156308     28.0     1.0        5.0
# 1      2021-04-01     768.024839  30202938     25.0     1.0        5.0
# 2      2021-04-01     386.127949  30153963     30.0     1.0        6.0
# 3      2021-04-01     202.411065  30349574     32.0     1.0        3.0
# 4      2021-04-01     785.526262  30211560     28.0     1.0        5.0
# ...           ...            ...       ...      ...     ...        ...
# 181668 2020-07-02     102.482422  30200854     25.0     1.0        5.0
# 181669 2020-07-02     208.086469  30200854     25.0     1.0        5.0
# 181670 2020-07-02       4.235594  30200854     25.0     1.0        5.0
# 181671 2020-07-02       0.000000  30200854     25.0     1.0        5.0
# 181672 2020-07-02     406.686538  30200854     25.0     1.0        5.0
#
#         application  thickness   width product_ref delivery_date  \
# 0              10.0       2.00  1500.0  1670798778    2021-07-01
# 1              41.0       0.80  1210.0  1668701718    2021-04-01
# 2              28.0       0.38   952.0      628377    2021-01-01
# 3              59.0       2.30  1317.0  1668701718    2021-01-01
# 4              10.0       4.00  2000.0      640665    2021-03-01
# ...             ...        ...     ...         ...           ...
# 181668         41.0       0.96  1220.0   164141591    2020-07-01
# 181669         41.0       0.95  1500.0   164141591    2020-07-01
# 181670         41.0       0.71  1250.0   164141591    2020-07-01
# 181671         41.0       0.85  1250.0   164141591    2020-07-01
# 181672         41.0       0.71  1240.0   164141591    2020-07-01
#
#         selling_price  item_date_day  item_date_year  item_date_month  \
# 0              854.00              1            2021                4
# 1             1047.00              1            2021                4
# 2              644.33              1            2021                4
# 3              768.00              1            2021                4
# 4              577.00              1            2021                4
# ...               ...            ...             ...              ...
# 181668         591.00              2            2020                7
# 181669         589.00              2            2020                7
# 181670         619.00              2            2020                7
# 181671         601.00              2            2020                7
# 181672         607.00              2            2020                7
#
#         delivery_date_day  delivery_date_month  delivery_date_year
# 0                       1                    7                2021
# 1                       1                    4                2021
# 2                       1                    1                2021
# 3                       1                    1                2021
# 4                       1                    3                2021
# ...                   ...                  ...                 ...
# 181668                  1                    7                2020
# 181669                  1                    7                2020
# 181670                  1                    7                2020
# 181671                  1                    7                2020
# 181672                  1                    7                2020
#
# [150444 rows x 18 columns]

# %%
import seaborn as sns

import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(13,8))
sns.heatmap(new_df.corr(),annot=True)
# Out:
# <ipython-input-241-0fc8cb98d573>:2: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# <Axes: >

# %% [markdown]
# ### **Treating Skewness**

# %%
new_df
# Out:
#         item_date  quantity_tons  customer  country  status  item_type  \
# 0      2021-04-01      54.151139  30156308     28.0     1.0        5.0
# 1      2021-04-01     768.024839  30202938     25.0     1.0        5.0
# 2      2021-04-01     386.127949  30153963     30.0     1.0        6.0
# 3      2021-04-01     202.411065  30349574     32.0     1.0        3.0
# 4      2021-04-01     785.526262  30211560     28.0     1.0        5.0
# ...           ...            ...       ...      ...     ...        ...
# 181668 2020-07-02     102.482422  30200854     25.0     1.0        5.0
# 181669 2020-07-02     208.086469  30200854     25.0     1.0        5.0
# 181670 2020-07-02       4.235594  30200854     25.0     1.0        5.0
# 181671 2020-07-02       0.000000  30200854     25.0     1.0        5.0
# 181672 2020-07-02     406.686538  30200854     25.0     1.0        5.0
#
#         application  thickness   width product_ref delivery_date  \
# 0              10.0       2.00  1500.0  1670798778    2021-07-01
# 1              41.0       0.80  1210.0  1668701718    2021-04-01
# 2              28.0       0.38   952.0      628377    2021-01-01
# 3              59.0       2.30  1317.0  1668701718    2021-01-01
# 4              10.0       4.00  2000.0      640665    2021-03-01
# ...             ...        ...     ...         ...           ...
# 181668         41.0       0.96  1220.0   164141591    2020-07-01
# 181669         41.0       0.95  1500.0   164141591    2020-07-01
# 181670         41.0       0.71  1250.0   164141591    2020-07-01
# 181671         41.0       0.85  1250.0   164141591    2020-07-01
# 181672         41.0       0.71  1240.0   164141591    2020-07-01
#
#         selling_price  item_date_day  item_date_year  item_date_month  \
# 0              854.00              1            2021                4
# 1             1047.00              1            2021                4
# 2              644.33              1            2021                4
# 3              768.00              1            2021                4
# 4              577.00              1            2021                4
# ...               ...            ...             ...              ...
# 181668         591.00              2            2020                7
# 181669         589.00              2            2020                7
# 181670         619.00              2            2020                7
# 181671         601.00              2            2020                7
# 181672         607.00              2            2020                7
#
#         delivery_date_day  delivery_date_month  delivery_date_year
# 0                       1                    7                2021
# 1                       1                    4                2021
# 2                       1                    1                2021
# 3                       1                    1                2021
# 4                       1                    3                2021
# ...                   ...                  ...                 ...
# 181668                  1                    7                2020
# 181669                  1                    7                2020
# 181670                  1                    7                2020
# 181671                  1                    7                2020
# 181672                  1                    7                2020
#
# [150444 rows x 18 columns]

# %%
columns = [ 'quantity_tons',  'application', 'thickness', 'width', 'selling_price', ]

# %% [markdown]
# ## **Before Treating Skewness**

# %%
from scipy.stats import norm
def before_skewness(column):
  for i in columns:
    sns.set_style("darkgrid")
    sns.histplot(new_df[i],kde=True,color='r')
    plt.title(f'Skewness In {i}')
    plt.show()

before_skewness(columns)

# %% [markdown]
# ## **After Treated The Skewness**

# %%
new_df_1 = new_df.copy()

# %% [markdown]
# **`Log Transoformation`**

# %%
columns
# Out:
# ['quantity_tons', 'application', 'thickness', 'width', 'selling_price']

# %%
import numpy as np
def log_transformation(column):
  for i in column:
    new_df_1[i] = np.log(new_df_1[i])

log_transformation(columns)
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log

# %%
def before_skewness(column):
  for i in columns:
    sns.set_style("darkgrid")
    sns.histplot(new_df_1[i],kde=True,color='g')
    plt.title(f'Skewness In {i}')
    plt.show()

before_skewness(columns)

# %% [markdown]
# ## **Treating Outliers With IQR Method**

# %%
new_df_1
# Out:
#         item_date  quantity_tons  customer  country  status  item_type  \
# 0      2021-04-01       3.991779  30156308     28.0     1.0        5.0
# 1      2021-04-01       6.643822  30202938     25.0     1.0        5.0
# 2      2021-04-01       5.956169  30153963     30.0     1.0        6.0
# 3      2021-04-01       5.310301  30349574     32.0     1.0        3.0
# 4      2021-04-01       6.666354  30211560     28.0     1.0        5.0
# ...           ...            ...       ...      ...     ...        ...
# 181668 2020-07-02       4.629691  30200854     25.0     1.0        5.0
# 181669 2020-07-02       5.337954  30200854     25.0     1.0        5.0
# 181670 2020-07-02       1.443523  30200854     25.0     1.0        5.0
# 181671 2020-07-02           -inf  30200854     25.0     1.0        5.0
# 181672 2020-07-02       6.008043  30200854     25.0     1.0        5.0
#
#         application  thickness     width product_ref delivery_date  \
# 0          2.302585   0.693147  7.313220  1670798778    2021-07-01
# 1          3.713572  -0.223144  7.098376  1668701718    2021-04-01
# 2          3.332205  -0.967584  6.858565      628377    2021-01-01
# 3          4.077537   0.832909  7.183112  1668701718    2021-01-01
# 4          2.302585   1.386294  7.600902      640665    2021-03-01
# ...             ...        ...       ...         ...           ...
# 181668     3.713572  -0.040822  7.106606   164141591    2020-07-01
# 181669     3.713572  -0.051293  7.313220   164141591    2020-07-01
# 181670     3.713572  -0.342490  7.130899   164141591    2020-07-01
# 181671     3.713572  -0.162519  7.130899   164141591    2020-07-01
# 181672     3.713572  -0.342490  7.122867   164141591    2020-07-01
#
#         selling_price  item_date_day  item_date_year  item_date_month  \
# 0            6.749931              1            2021                4
# 1            6.953684              1            2021                4
# 2            6.468211              1            2021                4
# 3            6.643790              1            2021                4
# 4            6.357842              1            2021                4
# ...               ...            ...             ...              ...
# 181668       6.381816              2            2020                7
# 181669       6.378426              2            2020                7
# 181670       6.428105              2            2020                7
# 181671       6.398595              2            2020                7
# 181672       6.408529              2            2020                7
#
#         delivery_date_day  delivery_date_month  delivery_date_year
# 0                       1                    7                2021
# 1                       1                    4                2021
# 2                       1                    1                2021
# 3                       1                    1                2021
# 4                       1                    3                2021
# ...                   ...                  ...                 ...
# 181668                  1                    7                2020
# 181669                  1                    7                2020
# 181670                  1                    7                2020
# 181671                  1                    7                2020
# 181672                  1                    7                2020
#
# [150444 rows x 18 columns]

# %% [markdown]
# ## **Before Treating Outliers**

# %%
import seaborn as sns
import matplotlib.pyplot as plt


def box_plot(columns):

  for i in columns:
    sns.boxplot(data=new_df_1,x=i)
    plt.title(f"Outliers in {i}")
    plt.show()

box_plot(['quantity_tons','thickness','width','selling_price'])

# %% [markdown]
# ## **After Treating Outliers**

# %%
import numpy as np

def treat_outliers(column):
  for i in column:
    iqr = np.percentile(new_df_1[i],75) - np.percentile(new_df_1[i],25)  # Q3 - Q1
    lower_bound =  np.percentile(new_df_1[i],25) - (1.5 * iqr)
    upper_bound = np.percentile(new_df_1[i],75) + (1.5 * iqr)
    new_df_1[i] = new_df_1[i].clip(lower_bound,upper_bound)
  print('Done !!!!')

treat_outliers(['quantity_tons','thickness','width','selling_price'])
# Out:
# Done !!!!

# %%
import seaborn as sns
import matplotlib.pyplot as plt


def box_plot(columns):

  for i in columns:
    sns.boxplot(data=new_df_1,x=i)
    plt.title(f"Outliers in {i}")
    plt.show()

box_plot(['quantity_tons','thickness','width','selling_price'])

# %% [markdown]
# ```
# # Note : We cleared all the outliers values !!!
# ```

# %% [markdown]
# ## **Handling Wrong Delivery Dates**

# %%
new_df_1
# Out:
#         item_date  quantity_tons  customer  country  status  item_type  \
# 0      2021-04-01       3.991779  30156308     28.0     1.0        5.0
# 1      2021-04-01       6.643822  30202938     25.0     1.0        5.0
# 2      2021-04-01       5.956169  30153963     30.0     1.0        6.0
# 3      2021-04-01       5.310301  30349574     32.0     1.0        3.0
# 4      2021-04-01       6.666354  30211560     28.0     1.0        5.0
# ...           ...            ...       ...      ...     ...        ...
# 181668 2020-07-02       4.629691  30200854     25.0     1.0        5.0
# 181669 2020-07-02       5.337954  30200854     25.0     1.0        5.0
# 181670 2020-07-02       1.443523  30200854     25.0     1.0        5.0
# 181671 2020-07-02      -0.333362  30200854     25.0     1.0        5.0
# 181672 2020-07-02       6.008043  30200854     25.0     1.0        5.0
#
#         application  thickness     width product_ref delivery_date  \
# 0          2.302585   0.693147  7.313220  1670798778    2021-07-01
# 1          3.713572  -0.223144  7.098376  1668701718    2021-04-01
# 2          3.332205  -0.967584  6.858565      628377    2021-01-01
# 3          4.077537   0.832909  7.183112  1668701718    2021-01-01
# 4          2.302585   1.386294  7.600902      640665    2021-03-01
# ...             ...        ...       ...         ...           ...
# 181668     3.713572  -0.040822  7.106606   164141591    2020-07-01
# 181669     3.713572  -0.051293  7.313220   164141591    2020-07-01
# 181670     3.713572  -0.342490  7.130899   164141591    2020-07-01
# 181671     3.713572  -0.162519  7.130899   164141591    2020-07-01
# 181672     3.713572  -0.342490  7.122867   164141591    2020-07-01
#
#         selling_price  item_date_day  item_date_year  item_date_month  \
# 0            6.749931              1            2021                4
# 1            6.953684              1            2021                4
# 2            6.468211              1            2021                4
# 3            6.643790              1            2021                4
# 4            6.357842              1            2021                4
# ...               ...            ...             ...              ...
# 181668       6.381816              2            2020                7
# 181669       6.378426              2            2020                7
# 181670       6.428105              2            2020                7
# 181671       6.398595              2            2020                7
# 181672       6.408529              2            2020                7
#
#         delivery_date_day  delivery_date_month  delivery_date_year
# 0                       1                    7                2021
# 1                       1                    4                2021
# 2                       1                    1                2021
# 3                       1                    1                2021
# 4                       1                    3                2021
# ...                   ...                  ...                 ...
# 181668                  1                    7                2020
# 181669                  1                    7                2020
# 181670                  1                    7                2020
# 181671                  1                    7                2020
# 181672                  1                    7                2020
#
# [150444 rows x 18 columns]

# %%
new_df_1['delivery_item_date_difference_num'] = (new_df_1['delivery_date']-new_df_1['item_date']).dt.days

# %%
positive = new_df_1[new_df_1['delivery_item_date_difference_num']>0]

# %%
len(positive)
# Out:
# 135369

# %%
new_df_1.corr()
# Out:
# <ipython-input-257-b36977e9310c>:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#                                    quantity_tons   country    status  \
# quantity_tons                           1.000000 -0.081176 -0.118736
# country                                -0.081176  1.000000  0.094776
# status                                 -0.118736  0.094776  1.000000
# item_type                              -0.320359  0.103671  0.234346
# application                             0.057215 -0.050131  0.169194
# thickness                               0.033888 -0.055567 -0.172087
# width                                   0.038058  0.052240 -0.121940
# selling_price                          -0.077404 -0.019119  0.043875
# item_date_day                           0.040658 -0.073176 -0.008525
# item_date_year                          0.005739 -0.025890  0.054885
# item_date_month                        -0.015129  0.035194 -0.023936
# delivery_date_day                       0.000096 -0.001831  0.001405
# delivery_date_month                    -0.014497  0.020763 -0.008393
# delivery_date_year                      0.020663 -0.064708 -0.030037
# delivery_item_date_difference_num       0.046912 -0.149061 -0.243161
#
#                                    item_type  application  thickness  \
# quantity_tons                      -0.320359     0.057215   0.033888
# country                             0.103671    -0.050131  -0.055567
# status                              0.234346     0.169194  -0.172087
# item_type                           1.000000     0.177692  -0.103355
# application                         0.177692     1.000000  -0.228374
# thickness                          -0.103355    -0.228374   1.000000
# width                              -0.097074    -0.193454   0.379250
# selling_price                       0.121387     0.174969  -0.471081
# item_date_day                      -0.050111    -0.017235  -0.006057
# item_date_year                      0.047057    -0.014379   0.019180
# item_date_month                    -0.017194     0.021551  -0.018664
# delivery_date_day                  -0.002930     0.004602  -0.002812
# delivery_date_month                -0.016735     0.000881  -0.014262
# delivery_date_year                  0.018766    -0.055035   0.048439
# delivery_item_date_difference_num  -0.084905    -0.173782   0.107881
#
#                                       width  selling_price  item_date_day  \
# quantity_tons                      0.038058      -0.077404       0.040658
# country                            0.052240      -0.019119      -0.073176
# status                            -0.121940       0.043875      -0.008525
# item_type                         -0.097074       0.121387      -0.050111
# application                       -0.193454       0.174969      -0.017235
# thickness                          0.379250      -0.471081      -0.006057
# width                              1.000000      -0.171265      -0.002038
# selling_price                     -0.171265       1.000000       0.013699
# item_date_day                     -0.002038       0.013699       1.000000
# item_date_year                     0.025726       0.579012       0.024672
# item_date_month                   -0.031029      -0.439421      -0.078856
# delivery_date_day                 -0.000320       0.000308      -0.000914
# delivery_date_month                0.019539      -0.190984       0.049202
# delivery_date_year                 0.010552       0.501126      -0.001206
# delivery_item_date_difference_num  0.056599       0.279829       0.023783
#
#                                    item_date_year  item_date_month  \
# quantity_tons                            0.005739        -0.015129
# country                                 -0.025890         0.035194
# status                                   0.054885        -0.023936
# item_type                                0.047057        -0.017194
# application                             -0.014379         0.021551
# thickness                                0.019180        -0.018664
# width                                    0.025726        -0.031029
# selling_price                            0.579012        -0.439421
# item_date_day                            0.024672        -0.078856
# item_date_year                           1.000000        -0.921427
# item_date_month                         -0.921427         1.000000
# delivery_date_day                       -0.002034         0.002753
# delivery_date_month                     -0.105350        -0.070172
# delivery_date_year                       0.548420        -0.299157
# delivery_item_date_difference_num        0.270725        -0.245511
#
#                                    delivery_date_day  delivery_date_month  \
# quantity_tons                               0.000096            -0.014497
# country                                    -0.001831             0.020763
# status                                      0.001405            -0.008393
# item_type                                  -0.002930            -0.016735
# application                                 0.004602             0.000881
# thickness                                  -0.002812            -0.014262
# width                                      -0.000320             0.019539
# selling_price                               0.000308            -0.190984
# item_date_day                              -0.000914             0.049202
# item_date_year                             -0.002034            -0.105350
# item_date_month                             0.002753            -0.070172
# delivery_date_day                           1.000000             0.004739
# delivery_date_month                         0.004739             1.000000
# delivery_date_year                          0.001801            -0.798340
# delivery_item_date_difference_num           0.016900            -0.109212
#
#                                    delivery_date_year  \
# quantity_tons                                0.020663
# country                                     -0.064708
# status                                      -0.030037
# item_type                                    0.018766
# application                                 -0.055035
# thickness                                    0.048439
# width                                        0.010552
# selling_price                                0.501126
# item_date_day                               -0.001206
# item_date_year                               0.548420
# item_date_month                             -0.299157
# delivery_date_day                            0.001801
# delivery_date_month                         -0.798340
# delivery_date_year                           1.000000
# delivery_item_date_difference_num            0.488065
#
#                                    delivery_item_date_difference_num
# quantity_tons                                               0.046912
# country                                                    -0.149061
# status                                                     -0.243161
# item_type                                                  -0.084905
# application                                                -0.173782
# thickness                                                   0.107881
# width                                                       0.056599
# selling_price                                               0.279829
# item_date_day                                               0.023783
# item_date_year                                              0.270725
# item_date_month                                            -0.245511
# delivery_date_day                                           0.016900
# delivery_date_month                                        -0.109212
# delivery_date_year                                          0.488065
# delivery_item_date_difference_num                           1.000000

# %%
new_df_1.head(2)
# Out:
#    item_date  quantity_tons  customer  country  status  item_type  \
# 0 2021-04-01       3.991779  30156308     28.0     1.0        5.0
# 1 2021-04-01       6.643822  30202938     25.0     1.0        5.0
#
#    application  thickness     width product_ref delivery_date  selling_price  \
# 0     2.302585   0.693147  7.313220  1670798778    2021-07-01       6.749931
# 1     3.713572  -0.223144  7.098376  1668701718    2021-04-01       6.953684
#
#    item_date_day  item_date_year  item_date_month  delivery_date_day  \
# 0              1            2021                4                  1
# 1              1            2021                4                  1
#
#    delivery_date_month  delivery_date_year  delivery_item_date_difference_num
# 0                    7                2021                                 91
# 1                    4                2021                                  0

# %% [markdown]
# **Model To Predict Delivery Date**

# %%
correct_delivery_dates_df = new_df_1.query('delivery_item_date_difference_num>0')

# %%
correct_delivery_dates_df
# Out:
#         item_date  quantity_tons  customer  country  status  item_type  \
# 0      2021-04-01       3.991779  30156308     28.0     1.0        5.0
# 8      2021-04-01       4.235147  30341428     38.0     1.0        3.0
# 12     2021-04-01       3.314642  30165529     78.0     1.0        5.0
# 13     2021-04-01       3.473063  30202362     27.0     1.0        3.0
# 17     2021-04-01       3.035295  30211222     30.0     1.0        5.0
# ...           ...            ...       ...      ...     ...        ...
# 181433 2020-07-02       3.472467  30227718     25.0     0.0        3.0
# 181525 2020-07-02       4.196171  30161559     30.0     0.0        3.0
# 181527 2020-07-02       4.156686  30161559     30.0     0.0        3.0
# 181529 2020-07-02       4.025862  30161559     30.0     0.0        3.0
# 181531 2020-07-02       5.328963  30161559     30.0     0.0        3.0
#
#         application  thickness     width product_ref delivery_date  \
# 0          2.302585   0.693147  7.313220  1670798778    2021-07-01
# 8          2.302585  -0.510826  7.150701  1668701376    2021-07-01
# 12         2.302585  -0.287682  7.130899   164141591    2021-07-01
# 13         2.302585  -0.510826  6.917706      628377    2021-07-01
# 17         2.302585  -0.798508  6.802395      611993    2021-07-01
# ...             ...        ...       ...         ...           ...
# 181433     2.708050   1.791759  7.600902      640665    2020-08-01
# 181525     2.302585   1.348073  7.329750      640665    2020-08-01
# 181527     2.302585   1.766442  7.329750      640665    2020-08-01
# 181529     2.302585   2.060514  7.313220      640665    2020-08-01
# 181531     2.302585   1.348073  7.512071      640665    2020-08-01
#
#         selling_price  item_date_day  item_date_year  item_date_month  \
# 0            6.749931              1            2021                4
# 8            7.217443              1            2021                4
# 12           7.001246              1            2021                4
# 13           6.880384              1            2021                4
# 17           7.181736              1            2021                4
# ...               ...            ...             ...              ...
# 181433       6.313548              2            2020                7
# 181525       6.126869              2            2020                7
# 181527       6.124683              2            2020                7
# 181529       6.126869              2            2020                7
# 181531       6.131226              2            2020                7
#
#         delivery_date_day  delivery_date_month  delivery_date_year  \
# 0                       1                    7                2021
# 8                       1                    7                2021
# 12                      1                    7                2021
# 13                      1                    7                2021
# 17                      1                    7                2021
# ...                   ...                  ...                 ...
# 181433                  1                    8                2020
# 181525                  1                    8                2020
# 181527                  1                    8                2020
# 181529                  1                    8                2020
# 181531                  1                    8                2020
#
#         delivery_item_date_difference_num
# 0                                      91
# 8                                      91
# 12                                     91
# 13                                     91
# 17                                     91
# ...                                   ...
# 181433                                 30
# 181525                                 30
# 181527                                 30
# 181529                                 30
# 181531                                 30
#
# [135369 rows x 19 columns]

# %%
wrong_delivery_dates_df = new_df_1.query('delivery_item_date_difference_num<=0')

# %%
wrong_delivery_dates_df
# Out:
#         item_date  quantity_tons  customer  country  status  item_type  \
# 1      2021-04-01       6.643822  30202938     25.0     1.0        5.0
# 2      2021-04-01       5.956169  30153963     30.0     1.0        6.0
# 3      2021-04-01       5.310301  30349574     32.0     1.0        3.0
# 4      2021-04-01       6.666354  30211560     28.0     1.0        5.0
# 5      2021-04-01       5.419608  30202938     25.0     1.0        5.0
# ...           ...            ...       ...      ...     ...        ...
# 181668 2020-07-02       4.629691  30200854     25.0     1.0        5.0
# 181669 2020-07-02       5.337954  30200854     25.0     1.0        5.0
# 181670 2020-07-02       1.443523  30200854     25.0     1.0        5.0
# 181671 2020-07-02      -0.333362  30200854     25.0     1.0        5.0
# 181672 2020-07-02       6.008043  30200854     25.0     1.0        5.0
#
#         application  thickness     width product_ref delivery_date  \
# 1          3.713572  -0.223144  7.098376  1668701718    2021-04-01
# 2          3.332205  -0.967584  6.858565      628377    2021-01-01
# 3          4.077537   0.832909  7.183112  1668701718    2021-01-01
# 4          2.302585   1.386294  7.600902      640665    2021-03-01
# 5          3.713572   0.405465  7.142827  1668701718    2021-04-01
# ...             ...        ...       ...         ...           ...
# 181668     3.713572  -0.040822  7.106606   164141591    2020-07-01
# 181669     3.713572  -0.051293  7.313220   164141591    2020-07-01
# 181670     3.713572  -0.342490  7.130899   164141591    2020-07-01
# 181671     3.713572  -0.162519  7.130899   164141591    2020-07-01
# 181672     3.713572  -0.342490  7.122867   164141591    2020-07-01
#
#         selling_price  item_date_day  item_date_year  item_date_month  \
# 1            6.953684              1            2021                4
# 2            6.468211              1            2021                4
# 3            6.643790              1            2021                4
# 4            6.357842              1            2021                4
# 5            6.890609              1            2021                4
# ...               ...            ...             ...              ...
# 181668       6.381816              2            2020                7
# 181669       6.378426              2            2020                7
# 181670       6.428105              2            2020                7
# 181671       6.398595              2            2020                7
# 181672       6.408529              2            2020                7
#
#         delivery_date_day  delivery_date_month  delivery_date_year  \
# 1                       1                    4                2021
# 2                       1                    1                2021
# 3                       1                    1                2021
# 4                       1                    3                2021
# 5                       1                    4                2021
# ...                   ...                  ...                 ...
# 181668                  1                    7                2020
# 181669                  1                    7                2020
# 181670                  1                    7                2020
# 181671                  1                    7                2020
# 181672                  1                    7                2020
#
#         delivery_item_date_difference_num
# 1                                       0
# 2                                     -90
# 3                                     -90
# 4                                     -31
# 5                                       0
# ...                                   ...
# 181668                                 -1
# 181669                                 -1
# 181670                                 -1
# 181671                                 -1
# 181672                                 -1
#
# [15075 rows x 19 columns]

# %%
correct_delivery_dates_df =  correct_delivery_dates_df.dropna()

# %%
correct_delivery_dates_df
# Out:
#         item_date  quantity_tons  customer  country  status  item_type  \
# 0      2021-04-01       3.991779  30156308     28.0     1.0        5.0
# 8      2021-04-01       4.235147  30341428     38.0     1.0        3.0
# 12     2021-04-01       3.314642  30165529     78.0     1.0        5.0
# 13     2021-04-01       3.473063  30202362     27.0     1.0        3.0
# 17     2021-04-01       3.035295  30211222     30.0     1.0        5.0
# ...           ...            ...       ...      ...     ...        ...
# 181433 2020-07-02       3.472467  30227718     25.0     0.0        3.0
# 181525 2020-07-02       4.196171  30161559     30.0     0.0        3.0
# 181527 2020-07-02       4.156686  30161559     30.0     0.0        3.0
# 181529 2020-07-02       4.025862  30161559     30.0     0.0        3.0
# 181531 2020-07-02       5.328963  30161559     30.0     0.0        3.0
#
#         application  thickness     width product_ref delivery_date  \
# 0          2.302585   0.693147  7.313220  1670798778    2021-07-01
# 8          2.302585  -0.510826  7.150701  1668701376    2021-07-01
# 12         2.302585  -0.287682  7.130899   164141591    2021-07-01
# 13         2.302585  -0.510826  6.917706      628377    2021-07-01
# 17         2.302585  -0.798508  6.802395      611993    2021-07-01
# ...             ...        ...       ...         ...           ...
# 181433     2.708050   1.791759  7.600902      640665    2020-08-01
# 181525     2.302585   1.348073  7.329750      640665    2020-08-01
# 181527     2.302585   1.766442  7.329750      640665    2020-08-01
# 181529     2.302585   2.060514  7.313220      640665    2020-08-01
# 181531     2.302585   1.348073  7.512071      640665    2020-08-01
#
#         selling_price  item_date_day  item_date_year  item_date_month  \
# 0            6.749931              1            2021                4
# 8            7.217443              1            2021                4
# 12           7.001246              1            2021                4
# 13           6.880384              1            2021                4
# 17           7.181736              1            2021                4
# ...               ...            ...             ...              ...
# 181433       6.313548              2            2020                7
# 181525       6.126869              2            2020                7
# 181527       6.124683              2            2020                7
# 181529       6.126869              2            2020                7
# 181531       6.131226              2            2020                7
#
#         delivery_date_day  delivery_date_month  delivery_date_year  \
# 0                       1                    7                2021
# 8                       1                    7                2021
# 12                      1                    7                2021
# 13                      1                    7                2021
# 17                      1                    7                2021
# ...                   ...                  ...                 ...
# 181433                  1                    8                2020
# 181525                  1                    8                2020
# 181527                  1                    8                2020
# 181529                  1                    8                2020
# 181531                  1                    8                2020
#
#         delivery_item_date_difference_num
# 0                                      91
# 8                                      91
# 12                                     91
# 13                                     91
# 17                                     91
# ...                                   ...
# 181433                                 30
# 181525                                 30
# 181527                                 30
# 181529                                 30
# 181531                                 30
#
# [135369 rows x 19 columns]

# %%
x = correct_delivery_dates_df[[ 'quantity_tons', 'customer', 'country', 'status',
       'item_type', 'application', 'thickness', 'width', 'product_ref',
        'selling_price', 'item_date_day', 'item_date_year',
       'item_date_month', 'delivery_date_day', 'delivery_date_month',
       'delivery_date_year',]]

y = correct_delivery_dates_df['delivery_item_date_difference_num']

# %%
from sklearn.model_selection import train_test_split

xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=0.2)

# %%
from sklearn.impute import SimpleImputer


imputer = SimpleImputer(strategy='mean')


xtrain = imputer.fit_transform(xtrain)

# %%
from sklearn.ensemble import RandomForestRegressor

model =  RandomForestRegressor().fit(xtrain,ytrain)

# %%
from sklearn.impute import SimpleImputer


imputer = SimpleImputer(strategy='mean')


xtest = imputer.fit_transform(xtest)

# %%
# predict
from sklearn.metrics import r2_score

xtest = pd.DataFrame(xtest,columns=[ 'quantity_tons', 'customer', 'country', 'status',
       'item_type', 'application', 'thickness', 'width', 'product_ref',
        'selling_price', 'item_date_day', 'item_date_year',
       'item_date_month', 'delivery_date_day', 'delivery_date_month',
       'delivery_date_year',])

ypred = model.predict(xtest)


score = r2_score(ytest,ypred)
score
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning:
#
# X has feature names, but RandomForestRegressor was fitted without feature names
# 0.9885360683327175

# %% [markdown]
# ```
# # Note : Now time to find delivery date for wrong_delivery_date_df
# ```

# %%
dates_predict = wrong_delivery_dates_df[[ 'quantity_tons', 'customer', 'country', 'status',
       'item_type', 'application', 'thickness', 'width', 'product_ref',
        'selling_price', 'item_date_day', 'item_date_year',
       'item_date_month', 'delivery_date_day', 'delivery_date_month',
       'delivery_date_year',]]

# %%
dates_predict
# Out:
#         quantity_tons  customer  country  status  item_type  application  \
# 1            6.643822  30202938     25.0     1.0        5.0     3.713572
# 2            5.956169  30153963     30.0     1.0        6.0     3.332205
# 3            5.310301  30349574     32.0     1.0        3.0     4.077537
# 4            6.666354  30211560     28.0     1.0        5.0     2.302585
# 5            5.419608  30202938     25.0     1.0        5.0     3.713572
# ...               ...       ...      ...     ...        ...          ...
# 181668       4.629691  30200854     25.0     1.0        5.0     3.713572
# 181669       5.337954  30200854     25.0     1.0        5.0     3.713572
# 181670       1.443523  30200854     25.0     1.0        5.0     3.713572
# 181671      -0.333362  30200854     25.0     1.0        5.0     3.713572
# 181672       6.008043  30200854     25.0     1.0        5.0     3.713572
#
#         thickness     width product_ref  selling_price  item_date_day  \
# 1       -0.223144  7.098376  1668701718       6.953684              1
# 2       -0.967584  6.858565      628377       6.468211              1
# 3        0.832909  7.183112  1668701718       6.643790              1
# 4        1.386294  7.600902      640665       6.357842              1
# 5        0.405465  7.142827  1668701718       6.890609              1
# ...           ...       ...         ...            ...            ...
# 181668  -0.040822  7.106606   164141591       6.381816              2
# 181669  -0.051293  7.313220   164141591       6.378426              2
# 181670  -0.342490  7.130899   164141591       6.428105              2
# 181671  -0.162519  7.130899   164141591       6.398595              2
# 181672  -0.342490  7.122867   164141591       6.408529              2
#
#         item_date_year  item_date_month  delivery_date_day  \
# 1                 2021                4                  1
# 2                 2021                4                  1
# 3                 2021                4                  1
# 4                 2021                4                  1
# 5                 2021                4                  1
# ...                ...              ...                ...
# 181668            2020                7                  1
# 181669            2020                7                  1
# 181670            2020                7                  1
# 181671            2020                7                  1
# 181672            2020                7                  1
#
#         delivery_date_month  delivery_date_year
# 1                         4                2021
# 2                         1                2021
# 3                         1                2021
# 4                         3                2021
# 5                         4                2021
# ...                     ...                 ...
# 181668                    7                2020
# 181669                    7                2020
# 181670                    7                2020
# 181671                    7                2020
# 181672                    7                2020
#
# [15075 rows x 16 columns]

# %%
yhat_dates = model.predict(dates_predict)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning:
#
# X has feature names, but RandomForestRegressor was fitted without feature names

# %%
yhat_dates  # We found correct dates for the wrong_delivery_dates_df
# Out:
# array([ 31.  , 156.62, 175.44, ...,  30.  ,  30.  ,  30.  ])

# %%
wrong_delivery_dates_df.drop('delivery_item_date_difference_num',axis=1,inplace=True)

wrong_delivery_dates_df['delivery_item_date_difference_num'] = yhat_dates

wrong_delivery_dates_df.drop('delivery_item_date_difference',axis=1,inplace=True)

# %%
wrong_delivery_dates_df['delivery_item_date_difference_num'] = wrong_delivery_dates_df['delivery_item_date_difference_num'].apply(lambda x : int(x))
# Out:
# <ipython-input-277-dfa5354bab09>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
wrong_delivery_dates_df
# Out:
#         item_date  quantity_tons  customer  country  status  item_type  \
# 1      2021-04-01       6.643822  30202938     25.0     1.0        5.0
# 2      2021-04-01       5.956169  30153963     30.0     1.0        6.0
# 3      2021-04-01       5.310301  30349574     32.0     1.0        3.0
# 4      2021-04-01       6.666354  30211560     28.0     1.0        5.0
# 5      2021-04-01       5.419608  30202938     25.0     1.0        5.0
# ...           ...            ...       ...      ...     ...        ...
# 181668 2020-07-02       4.629691  30200854     25.0     1.0        5.0
# 181669 2020-07-02       5.337954  30200854     25.0     1.0        5.0
# 181670 2020-07-02       1.443523  30200854     25.0     1.0        5.0
# 181671 2020-07-02      -0.333362  30200854     25.0     1.0        5.0
# 181672 2020-07-02       6.008043  30200854     25.0     1.0        5.0
#
#         application  thickness     width product_ref delivery_date  \
# 1          3.713572  -0.223144  7.098376  1668701718    2021-04-01
# 2          3.332205  -0.967584  6.858565      628377    2021-01-01
# 3          4.077537   0.832909  7.183112  1668701718    2021-01-01
# 4          2.302585   1.386294  7.600902      640665    2021-03-01
# 5          3.713572   0.405465  7.142827  1668701718    2021-04-01
# ...             ...        ...       ...         ...           ...
# 181668     3.713572  -0.040822  7.106606   164141591    2020-07-01
# 181669     3.713572  -0.051293  7.313220   164141591    2020-07-01
# 181670     3.713572  -0.342490  7.130899   164141591    2020-07-01
# 181671     3.713572  -0.162519  7.130899   164141591    2020-07-01
# 181672     3.713572  -0.342490  7.122867   164141591    2020-07-01
#
#         selling_price  item_date_day  item_date_year  item_date_month  \
# 1            6.953684              1            2021                4
# 2            6.468211              1            2021                4
# 3            6.643790              1            2021                4
# 4            6.357842              1            2021                4
# 5            6.890609              1            2021                4
# ...               ...            ...             ...              ...
# 181668       6.381816              2            2020                7
# 181669       6.378426              2            2020                7
# 181670       6.428105              2            2020                7
# 181671       6.398595              2            2020                7
# 181672       6.408529              2            2020                7
#
#         delivery_date_day  delivery_date_month  delivery_date_year  \
# 1                       1                    4                2021
# 2                       1                    1                2021
# 3                       1                    1                2021
# 4                       1                    3                2021
# 5                       1                    4                2021
# ...                   ...                  ...                 ...
# 181668                  1                    7                2020
# 181669                  1                    7                2020
# 181670                  1                    7                2020
# 181671                  1                    7                2020
# 181672                  1                    7                2020
#
#         delivery_item_date_difference_num
# 1                                      31
# 2                                     156
# 3                                     175
# 4                                      31
# 5                                      31
# ...                                   ...
# 181668                                 30
# 181669                                 30
# 181670                                 30
# 181671                                 30
# 181672                                 30
#
# [15075 rows x 19 columns]

# %%
# correct_delivery_dates_df.drop('delivery_item_date_difference',axis=1,inplace=True)

# correct_delivery_dates_df

# %%
cleaned_data = pd.concat([correct_delivery_dates_df,wrong_delivery_dates_df],axis=0,ignore_index=True)

# %%
cleaned_data
# Out:
#         item_date  quantity_tons  customer  country  status  item_type  \
# 0      2021-04-01       3.991779  30156308     28.0     1.0        5.0
# 1      2021-04-01       4.235147  30341428     38.0     1.0        3.0
# 2      2021-04-01       3.314642  30165529     78.0     1.0        5.0
# 3      2021-04-01       3.473063  30202362     27.0     1.0        3.0
# 4      2021-04-01       3.035295  30211222     30.0     1.0        5.0
# ...           ...            ...       ...      ...     ...        ...
# 150439 2020-07-02       4.629691  30200854     25.0     1.0        5.0
# 150440 2020-07-02       5.337954  30200854     25.0     1.0        5.0
# 150441 2020-07-02       1.443523  30200854     25.0     1.0        5.0
# 150442 2020-07-02      -0.333362  30200854     25.0     1.0        5.0
# 150443 2020-07-02       6.008043  30200854     25.0     1.0        5.0
#
#         application  thickness     width product_ref delivery_date  \
# 0          2.302585   0.693147  7.313220  1670798778    2021-07-01
# 1          2.302585  -0.510826  7.150701  1668701376    2021-07-01
# 2          2.302585  -0.287682  7.130899   164141591    2021-07-01
# 3          2.302585  -0.510826  6.917706      628377    2021-07-01
# 4          2.302585  -0.798508  6.802395      611993    2021-07-01
# ...             ...        ...       ...         ...           ...
# 150439     3.713572  -0.040822  7.106606   164141591    2020-07-01
# 150440     3.713572  -0.051293  7.313220   164141591    2020-07-01
# 150441     3.713572  -0.342490  7.130899   164141591    2020-07-01
# 150442     3.713572  -0.162519  7.130899   164141591    2020-07-01
# 150443     3.713572  -0.342490  7.122867   164141591    2020-07-01
#
#         selling_price  item_date_day  item_date_year  item_date_month  \
# 0            6.749931              1            2021                4
# 1            7.217443              1            2021                4
# 2            7.001246              1            2021                4
# 3            6.880384              1            2021                4
# 4            7.181736              1            2021                4
# ...               ...            ...             ...              ...
# 150439       6.381816              2            2020                7
# 150440       6.378426              2            2020                7
# 150441       6.428105              2            2020                7
# 150442       6.398595              2            2020                7
# 150443       6.408529              2            2020                7
#
#         delivery_date_day  delivery_date_month  delivery_date_year  \
# 0                       1                    7                2021
# 1                       1                    7                2021
# 2                       1                    7                2021
# 3                       1                    7                2021
# 4                       1                    7                2021
# ...                   ...                  ...                 ...
# 150439                  1                    7                2020
# 150440                  1                    7                2020
# 150441                  1                    7                2020
# 150442                  1                    7                2020
# 150443                  1                    7                2020
#
#         delivery_item_date_difference_num
# 0                                      91
# 1                                      91
# 2                                      91
# 3                                      91
# 4                                      91
# ...                                   ...
# 150439                                 30
# 150440                                 30
# 150441                                 30
# 150442                                 30
# 150443                                 30
#
# [150444 rows x 19 columns]

# %%
cleaned_data.drop(['item_date','delivery_date',],axis=1,inplace=True)

# %%
cleaned_data
# Out:
#         quantity_tons  customer  country  status  item_type  application  \
# 0            3.991779  30156308     28.0     1.0        5.0     2.302585
# 1            4.235147  30341428     38.0     1.0        3.0     2.302585
# 2            3.314642  30165529     78.0     1.0        5.0     2.302585
# 3            3.473063  30202362     27.0     1.0        3.0     2.302585
# 4            3.035295  30211222     30.0     1.0        5.0     2.302585
# ...               ...       ...      ...     ...        ...          ...
# 150439       4.629691  30200854     25.0     1.0        5.0     3.713572
# 150440       5.337954  30200854     25.0     1.0        5.0     3.713572
# 150441       1.443523  30200854     25.0     1.0        5.0     3.713572
# 150442      -0.333362  30200854     25.0     1.0        5.0     3.713572
# 150443       6.008043  30200854     25.0     1.0        5.0     3.713572
#
#         thickness     width product_ref  selling_price  item_date_day  \
# 0        0.693147  7.313220  1670798778       6.749931              1
# 1       -0.510826  7.150701  1668701376       7.217443              1
# 2       -0.287682  7.130899   164141591       7.001246              1
# 3       -0.510826  6.917706      628377       6.880384              1
# 4       -0.798508  6.802395      611993       7.181736              1
# ...           ...       ...         ...            ...            ...
# 150439  -0.040822  7.106606   164141591       6.381816              2
# 150440  -0.051293  7.313220   164141591       6.378426              2
# 150441  -0.342490  7.130899   164141591       6.428105              2
# 150442  -0.162519  7.130899   164141591       6.398595              2
# 150443  -0.342490  7.122867   164141591       6.408529              2
#
#         item_date_year  item_date_month  delivery_date_day  \
# 0                 2021                4                  1
# 1                 2021                4                  1
# 2                 2021                4                  1
# 3                 2021                4                  1
# 4                 2021                4                  1
# ...                ...              ...                ...
# 150439            2020                7                  1
# 150440            2020                7                  1
# 150441            2020                7                  1
# 150442            2020                7                  1
# 150443            2020                7                  1
#
#         delivery_date_month  delivery_date_year  \
# 0                         7                2021
# 1                         7                2021
# 2                         7                2021
# 3                         7                2021
# 4                         7                2021
# ...                     ...                 ...
# 150439                    7                2020
# 150440                    7                2020
# 150441                    7                2020
# 150442                    7                2020
# 150443                    7                2020
#
#         delivery_item_date_difference_num
# 0                                      91
# 1                                      91
# 2                                      91
# 3                                      91
# 4                                      91
# ...                                   ...
# 150439                                 30
# 150440                                 30
# 150441                                 30
# 150442                                 30
# 150443                                 30
#
# [150444 rows x 17 columns]

# %%
cleaned_data.columns
# Out:
# Index(['quantity_tons', 'customer', 'country', 'status', 'item_type',
#        'application', 'thickness', 'width', 'product_ref', 'selling_price',
#        'item_date_day', 'item_date_year', 'item_date_month',
#        'delivery_date_day', 'delivery_date_month', 'delivery_date_year',
#        'delivery_item_date_difference_num'],
#       dtype='object')

# %%
cleaned_data = cleaned_data[['quantity_tons', 'customer', 'country', 'item_type',
       'application', 'thickness', 'width', 'product_ref',
       'item_date_day', 'item_date_month', 'item_date_year',
       'delivery_date_day', 'delivery_date_month', 'delivery_date_year',
       'delivery_item_date_difference_num','selling_price', 'status']]

# %%
cleaned_data.corr()
# Out:
# <ipython-input-286-10e03894f90d>:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#                                    quantity_tons   country  item_type  \
# quantity_tons                           1.000000 -0.081176  -0.320359
# country                                -0.081176  1.000000   0.103671
# item_type                              -0.320359  0.103671   1.000000
# application                             0.057215 -0.050131   0.177692
# thickness                               0.033888 -0.055567  -0.103355
# width                                   0.038058  0.052240  -0.097074
# item_date_day                           0.040658 -0.073176  -0.050111
# item_date_month                        -0.015129  0.035194  -0.017194
# item_date_year                          0.005739 -0.025890   0.047057
# delivery_date_day                       0.000096 -0.001831  -0.002930
# delivery_date_month                    -0.014497  0.020763  -0.016735
# delivery_date_year                      0.020663 -0.064708   0.018766
# delivery_item_date_difference_num       0.068660 -0.203466  -0.096970
# selling_price                          -0.077404 -0.019119   0.121387
# status                                 -0.118736  0.094776   0.234346
#
#                                    application  thickness     width  \
# quantity_tons                         0.057215   0.033888  0.038058
# country                              -0.050131  -0.055567  0.052240
# item_type                             0.177692  -0.103355 -0.097074
# application                           1.000000  -0.228374 -0.193454
# thickness                            -0.228374   1.000000  0.379250
# width                                -0.193454   0.379250  1.000000
# item_date_day                        -0.017235  -0.006057 -0.002038
# item_date_month                       0.021551  -0.018664 -0.031029
# item_date_year                       -0.014379   0.019180  0.025726
# delivery_date_day                     0.004602  -0.002812 -0.000320
# delivery_date_month                   0.000881  -0.014262  0.019539
# delivery_date_year                   -0.055035   0.048439  0.010552
# delivery_item_date_difference_num    -0.146327   0.083226  0.036621
# selling_price                         0.174969  -0.471081 -0.171265
# status                                0.169194  -0.172087 -0.121940
#
#                                    item_date_day  item_date_month  \
# quantity_tons                           0.040658        -0.015129
# country                                -0.073176         0.035194
# item_type                              -0.050111        -0.017194
# application                            -0.017235         0.021551
# thickness                              -0.006057        -0.018664
# width                                  -0.002038        -0.031029
# item_date_day                           1.000000        -0.078856
# item_date_month                        -0.078856         1.000000
# item_date_year                          0.024672        -0.921427
# delivery_date_day                      -0.000914         0.002753
# delivery_date_month                     0.049202        -0.070172
# delivery_date_year                     -0.001206        -0.299157
# delivery_item_date_difference_num      -0.010454        -0.303523
# selling_price                           0.013699        -0.439421
# status                                 -0.008525        -0.023936
#
#                                    item_date_year  delivery_date_day  \
# quantity_tons                            0.005739           0.000096
# country                                 -0.025890          -0.001831
# item_type                                0.047057          -0.002930
# application                             -0.014379           0.004602
# thickness                                0.019180          -0.002812
# width                                    0.025726          -0.000320
# item_date_day                            0.024672          -0.000914
# item_date_month                         -0.921427           0.002753
# item_date_year                           1.000000          -0.002034
# delivery_date_day                       -0.002034           1.000000
# delivery_date_month                     -0.105350           0.004739
# delivery_date_year                       0.548420           0.001801
# delivery_item_date_difference_num        0.307476           0.018475
# selling_price                            0.579012           0.000308
# status                                   0.054885           0.001405
#
#                                    delivery_date_month  delivery_date_year  \
# quantity_tons                                -0.014497            0.020663
# country                                       0.020763           -0.064708
# item_type                                    -0.016735            0.018766
# application                                   0.000881           -0.055035
# thickness                                    -0.014262            0.048439
# width                                         0.019539            0.010552
# item_date_day                                 0.049202           -0.001206
# item_date_month                              -0.070172           -0.299157
# item_date_year                               -0.105350            0.548420
# delivery_date_day                             0.004739            0.001801
# delivery_date_month                           1.000000           -0.798340
# delivery_date_year                           -0.798340            1.000000
# delivery_item_date_difference_num            -0.142606            0.468105
# selling_price                                -0.190984            0.501126
# status                                       -0.008393           -0.030037
#
#                                    delivery_item_date_difference_num  \
# quantity_tons                                               0.068660
# country                                                    -0.203466
# item_type                                                  -0.096970
# application                                                -0.146327
# thickness                                                   0.083226
# width                                                       0.036621
# item_date_day                                              -0.010454
# item_date_month                                            -0.303523
# item_date_year                                              0.307476
# delivery_date_day                                           0.018475
# delivery_date_month                                        -0.142606
# delivery_date_year                                          0.468105
# delivery_item_date_difference_num                           1.000000
# selling_price                                               0.286091
# status                                                     -0.216313
#
#                                    selling_price    status
# quantity_tons                          -0.077404 -0.118736
# country                                -0.019119  0.094776
# item_type                               0.121387  0.234346
# application                             0.174969  0.169194
# thickness                              -0.471081 -0.172087
# width                                  -0.171265 -0.121940
# item_date_day                           0.013699 -0.008525
# item_date_month                        -0.439421 -0.023936
# item_date_year                          0.579012  0.054885
# delivery_date_day                       0.000308  0.001405
# delivery_date_month                    -0.190984 -0.008393
# delivery_date_year                      0.501126 -0.030037
# delivery_item_date_difference_num       0.286091 -0.216313
# selling_price                           1.000000  0.043875
# status                                  0.043875  1.000000

# %%
cleaned_data.isnull().sum()
# Out:
# quantity_tons                        0
# customer                             0
# country                              0
# item_type                            0
# application                          0
# thickness                            0
# width                                0
# product_ref                          0
# item_date_day                        0
# item_date_month                      0
# item_date_year                       0
# delivery_date_day                    0
# delivery_date_month                  0
# delivery_date_year                   0
# delivery_item_date_difference_num    0
# selling_price                        0
# status                               0
# dtype: int64

# %%
cleaned_data.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ##**Cleaned Dataset**

# %% [markdown]
# ```
# # Here you can download the cleaned dataset
# ```

# %%
cleaned_data.to_csv('icm_cleaned_data.csv',index=False)

# %% [markdown]
# ```
#                                                          Finished
# ```
